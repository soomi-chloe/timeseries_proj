# %% [markdown]
# 데이터 다운로드

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # 1. 데이터 다운로드 (직접 URL 참조)
# url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
# df = pd.read_csv(url)

# # 2. 현업 수준의 시계열 전처리
# # 'Month' 컬럼을 datetime 객체로 변환하고 인덱스로 설정
# df['Month'] = pd.to_datetime(df['Month'])
# df.set_index('Month', inplace=True)

# # 컬럼명 명확화 (예측 타겟: Passengers)
# df.columns = ['Passengers']

# print(df.head())
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
# !streamlit run app.py
# Out:
# ^C
